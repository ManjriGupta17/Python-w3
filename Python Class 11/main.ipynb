# %%
print("Hello World")
# Out:
# Hello World

# %%
name="Manjri Gupta"
age=17
print("My name is",name,"I am",age,"years old")
print(f"My name is {name} and my age is {age} years old ")
# Out:
# My name is Manjri Gupta I am 17 years old
# My name is Manjri Gupta and my age is 17 years old

# %%
a = 10 
print(type(a))
# Out:
# <class 'int'>

# %%
a = 4/2
print(a)
# Out:
# 2.0

# %%
a = "4j"
print(a)
print(type(a))
# Out:
# 4j
# <class 'str'>

# %%
a = 0
b = ""
c = 1
print(a)
print(b)
print(c)
# Out:
# 0
#
# 1

# %%
print(ord("b"))
# Out:
# 98

# %%
print(chr(97))
# Out:
# a

# %%
a = "Hello World"
print(a[1:7:2])
# Out:
# el

# %%
a = 23
b = 22.5
c = "Vardhman Gupta"
d = True
# print(type(int(c)))
# print(type(float(c)))
print(type(str(d)))
# Out:
# <class 'str'>

# %%
name = input("Enter your beautiful name: ")
age = int(input("Enter your age: "))
print(f"My name is {name} and I am {age} years old")

# %%
num = int(input("Which table you want?: "))
for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
#   Cell In[4], line 3
#     print(num,"X",i "=" num*i)
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
num = int(input("Which table you want?: "))
for i in range(1, 11):
    print(f"{num} * {i} = {num * i}")
# Out:
# 356 * 1 = 356
# 356 * 2 = 712
# 356 * 3 = 1068
# 356 * 4 = 1424
# 356 * 5 = 1780
# 356 * 6 = 2136
# 356 * 7 = 2492
# 356 * 8 = 2848
# 356 * 9 = 3204
# 356 * 10 = 3560
